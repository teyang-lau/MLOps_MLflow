# %%
import pandas as pd
import pandera as pa

# %%
data = pd.read_csv("/home/teyang/projects/mlops_mlflow/data/resale-flat-prices-2022-jan.csv")
data
# Out:
#         month        town         flat_type block        street_name  \
# 0     2022-01  ANG MO KIO            2 ROOM   323   ANG MO KIO AVE 3
# 1     2022-01  ANG MO KIO            3 ROOM   320   ANG MO KIO AVE 1
# 2     2022-01  ANG MO KIO            3 ROOM   225   ANG MO KIO AVE 1
# 3     2022-01  ANG MO KIO            3 ROOM   331   ANG MO KIO AVE 1
# 4     2022-01  ANG MO KIO            3 ROOM   534  ANG MO KIO AVE 10
# ...       ...         ...               ...   ...                ...
# 2437  2022-01      YISHUN         EXECUTIVE   324        YISHUN CTRL
# 2438  2022-01      YISHUN         EXECUTIVE   325        YISHUN CTRL
# 2439  2022-01      YISHUN         EXECUTIVE   355     YISHUN RING RD
# 2440  2022-01      YISHUN         EXECUTIVE  640A       YISHUN ST 61
# 2441  2022-01      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#      storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
schema = pa.infer_schema(data)

# %%
list(data.dtypes)
# Out:
# [dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64')]

# %%
data.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# dtype: object

# %%
import mlflow
from mlflow.tracking import MlflowClient
with mlflow.start_run() as mlrun:
    exp_id = mlrun.info.experiment_id
    client = MlflowClient()
    all_runs = reversed(client.search_runs([exp_id]))
    if all_runs:
        print('YES')
# Out:
# YES

# %%
schema = {}
for col in data.columns:
    dt = data[col].dtype
    if dt.kind in 'iufc':
        schema[col] = {"type": str(dt), "min": float(data[col].min()), "max": float(data[col].max())}
    else:
        schema[col] = {"type": str(dt), "domain": list(set(data[col]))}

schema
# Out:
# {'month': {'type': 'object', 'domain': ['2022-01']},
#  'town': {'type': 'object',
#   'domain': ['YISHUN',
#    'TAMPINES',
#    'JURONG WEST',
#    'ANG MO KIO',
#    'GEYLANG',
#    'SERANGOON',
#    'CENTRAL AREA',
#    'SENGKANG',
#    'TOA PAYOH',
#    'KALLANG/WHAMPOA',
#    'BUKIT PANJANG',
#    'WOODLANDS',
#    'BUKIT BATOK',
#    'BISHAN',
#    'HOUGANG',
#    'SEMBAWANG',
#    'PASIR RIS',
#    'CLEMENTI',
#    'QUEENSTOWN',
#    'BUKIT TIMAH',
#    'BEDOK',
#    'CHOA CHU KANG',
#    'JURONG EAST',
#    'PUNGGOL',
#    'MARINE PARADE',
#    'BUKIT MERAH']},
#  'flat_type': {'type': 'object',
#   'domain': ['4 ROOM',
#    'MULTI-GENERATION',
#    '3 ROOM',
#    '5 ROOM',
#    'EXECUTIVE',
#    '2 ROOM']},
#  'block': {'type': 'object',
#   'domain': ['297A',
#    '158',
#    '672D',
#    '752',
#    '287',
#    '427',
#    '303D',
#    '105A',
#    '27',
#    '342B',
#    '527C',
#    '669B',
#    '316B',
#    '459',
#    '162',
#    '690D',
#    '679',
#    '455',
# ...

# %%
round(float("inf"),2)
# Out:
# inf

# %%
tmp = {'haha', 'BISHAN'}
tmp2 = {'BISHAN'}
diff = tmp.difference(tmp2)
if diff:
    print('YES')
# Out:
# YES

# %%
import json

with open("schema.json", "w") as file:
    json.dump(schema, file)

# %%
with open("schema.json", "r") as read_file:
   schema1 = json.load(read_file)
schema1
# Out:
# {'month': {'type': 'object', 'domain': ['2022-01']},
#  'town': {'type': 'object',
#   'domain': ['YISHUN',
#    'TAMPINES',
#    'JURONG WEST',
#    'ANG MO KIO',
#    'GEYLANG',
#    'SERANGOON',
#    'CENTRAL AREA',
#    'SENGKANG',
#    'TOA PAYOH',
#    'KALLANG/WHAMPOA',
#    'BUKIT PANJANG',
#    'WOODLANDS',
#    'BUKIT BATOK',
#    'BISHAN',
#    'HOUGANG',
#    'SEMBAWANG',
#    'PASIR RIS',
#    'CLEMENTI',
#    'QUEENSTOWN',
#    'BUKIT TIMAH',
#    'BEDOK',
#    'CHOA CHU KANG',
#    'JURONG EAST',
#    'PUNGGOL',
#    'MARINE PARADE',
#    'BUKIT MERAH']},
#  'flat_type': {'type': 'object',
#   'domain': ['4 ROOM',
#    'MULTI-GENERATION',
#    '3 ROOM',
#    '5 ROOM',
#    'EXECUTIVE',
#    '2 ROOM']},
#  'block': {'type': 'object',
#   'domain': ['297A',
#    '158',
#    '672D',
#    '752',
#    '287',
#    '427',
#    '303D',
#    '105A',
#    '27',
#    '342B',
#    '527C',
#    '669B',
#    '316B',
#    '459',
#    '162',
#    '690D',
#    '679',
#    '455',
# ...

# %%
import warnings
data1 = data.copy()
data1.at[0, "resale_price"] = 5000000
# data1['resale_price'] = data1['resale_price'].astype(str)
data1.at[0, "flat_type"] = "hoho"
data1.at[1, "flat_type"] = "hohe"
for col in data1.columns:
    if col not in schema1:
        print("Column {} is missing from dataset".format(col))
        break
    dt = data1[col].dtype
    if dt.kind in 'iufc':
        if dt != schema1[col]["type"]:
            print("Expected column `{}` to be \"{}\" but got \"{}\"".format(col, schema1[col]["type"], dt))
            print("Terminating data validation ...")
            break
        d_max, d_min = data1[col].max(), data1[col].min()
        if d_max > schema1[col]["max"] :
            warnings.warn("Column `{}` has values ({}) higher than max of schema ({})".format(col, d_max, schema1[col]["max"]))
        if d_min < schema1[col]["min"]:
            warnings.warn("Column `{}` has values ({}) lower than min of schema ({})".format(col, d_min, schema1[col]["min"]))
            break
    else: # if object
        if dt != schema1[col]["type"]:
            print("Expected column `{}` to be \"{}\" but got \"{}\"".format(col, schema1[col]["type"], dt))
            print("Terminating data validation ...")
            break
        old_set = set(schema1[col]["domain"])
        diff = set(data1[col]).difference(old_set)
        if diff:
            print("Column `{}` domain contains \"{}\" that are not present in schema".format(col, diff))
            print("Terminating data validation ...")
            break
# Out:
# Column `flat_type` domain contains "{'hohe', 'hoho'}" that are not present in schema
# Terminating data validation ...

# %%
dt.kind in 'iufc'
# Out:
# False

# %%
warnings.warn("Column '{}' has values ({}) higher than max of schema".format(col, d_max))
# Out:
# /tmp/ipykernel_86696/1041700813.py:1: UserWarning: Column 'resale_price' has values (1338888.0) higher than max of schema
#   warnings.warn("Column '{}' has values ({}) higher than max of schema".format(col, d_max))

# %%
tmp & schema.get("town")['domain']
# Out:
# set()

# %%
list(data['flat_type'].unique())
# Out:
# ['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', 'MULTI-GENERATION']

# %%
data['resale_price'].dtype.kind
# Out:
# 'f'

# %%
str(data[['flat_type']].dtypes[0])
# Out:
# True

# %%
data.dtypes[0]
# Out:
# dtype('O')

# %%
print(schema)
# Out:
# <Schema DataFrameSchema(
#     columns={
#         'month': <Schema Column(name=month, type=DataType(object))>
#         'town': <Schema Column(name=town, type=DataType(object))>
#         'flat_type': <Schema Column(name=flat_type, type=DataType(object))>
#         'block': <Schema Column(name=block, type=DataType(object))>
#         'street_name': <Schema Column(name=street_name, type=DataType(object))>
#         'storey_range': <Schema Column(name=storey_range, type=DataType(object))>
#         'floor_area_sqm': <Schema Column(name=floor_area_sqm, type=DataType(float64))>
#         'flat_model': <Schema Column(name=flat_model, type=DataType(object))>
#         'lease_commence_date': <Schema Column(name=lease_commence_date, type=DataType(int64))>
#         'remaining_lease': <Schema Column(name=remaining_lease, type=DataType(object))>
#         'resale_price': <Schema Column(name=resale_price, type=DataType(float64))>
#     },
#     checks=[],
#     coerce=True,
#     dtype=None,
# ...

# %%
client = MlflowClient()
all_runs = reversed(client.search_runs(['0']))

# %%
for runs in all_runs:
    print(runs)
# Out:
# <Run: data=<RunData: metrics={}, params={}, tags={'mlflow.runName': 'bald-fly-359',
#  'mlflow.source.git.commit': '2296069324c919b8f746df103938c51efa1bdc15',
#  'mlflow.source.name': '/home/teyang/projects/mlops_mlflow/venv/lib/python3.10/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'teyang'}>, info=<RunInfo: artifact_uri='file:///home/teyang/projects/mlops_mlflow/scripts/mlruns/0/c22237e6296941888276a71d06db71e4/artifacts', end_time=1686309962309, experiment_id='0', lifecycle_stage='active', run_id='c22237e6296941888276a71d06db71e4', run_name='bald-fly-359', run_uuid='c22237e6296941888276a71d06db71e4', start_time=1686309962301, status='FINISHED', user_id='teyang'>, inputs=<RunInputs: dataset_inputs=[]>>
# <Run: data=<RunData: metrics={}, params={}, tags={'mlflow.runName': 'amazing-dog-377',
#  'mlflow.source.git.commit': '2296069324c919b8f746df103938c51efa1bdc15',
# ...
